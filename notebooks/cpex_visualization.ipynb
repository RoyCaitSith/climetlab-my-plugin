# %% [markdown]
# # Hurricane Ian (2022)

# %%
# Download ibtracs
#wget https://www.ncei.noaa.gov/data/international-best-track-archive-for-climate-stewardship-ibtracs/v04r00/access/csv/ibtracs.ALL.list.v04r00.csv
#wget https://www.ncei.noaa.gov/data/international-best-track-archive-for-climate-stewardship-ibtracs/v04r00/access/csv/ibtracs.NA.list.v04r00.csv

# %%
from data_library import attributes
import climetlab as cml

(dir_case, case_name) = ('/08_CPEX_CV/01_AEW06_Ian', 'Ian')

case_attributes = attributes[(dir_case, case_name)]
ibtracs = cml.load_source('file', case_attributes['ibtracs'])
pd = ibtracs.to_pandas()
pd = pd[(pd.NAME == case_attributes['ibtracs_case']) & (pd.SEASON == case_attributes['ibtracs_season'])]
cml.plot_map(pd, style="cyclone-track")
pd
# Out:
# /uufs/chpc.utah.edu/common/home/zpu-group16/cfeng/mymini3/lib/python3.10/site-packages/climetlab/readers/csv.py:146: DtypeWarning: Columns (1,2,8,9,14,19,20,161,162) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pandas.read_csv(self.path, **pandas_read_csv_kwargs)
#                   SID SEASON NUMBER BASIN SUBBASIN NAME             ISO_TIME  \
# 709435  2022266N12294   2022     34   NaN       CS  IAN  2022-09-22 18:00:00
# 709436  2022266N12294   2022     34   NaN       CS  IAN  2022-09-22 21:00:00
# 709437  2022266N12294   2022     34   NaN       CS  IAN  2022-09-23 00:00:00
# 709438  2022266N12294   2022     34   NaN       CS  IAN  2022-09-23 03:00:00
# 709439  2022266N12294   2022     34   NaN       CS  IAN  2022-09-23 06:00:00
# ...               ...    ...    ...   ...      ...  ...                  ...
# 709504  2022266N12294   2022     34   NaN      NaN  IAN  2022-09-30 18:05:00
# 709505  2022266N12294   2022     34   NaN      NaN  IAN  2022-09-30 21:00:00
# 709506  2022266N12294   2022     34   NaN      NaN  IAN  2022-10-01 00:00:00
# 709507  2022266N12294   2022     34   NaN      NaN  IAN  2022-10-01 03:00:00
# 709508  2022266N12294   2022     34   NaN      NaN  IAN  2022-10-01 06:00:00
#
#        NATURE      LAT      LON  ... BOM_GUST_PER REUNION_GUST  \
# 709435     DS     12.3    -66.3  ...
# 709436     DS  12.5727 -66.7574  ...
# 709437     DS     12.9    -67.2  ...
# 709438     DS  13.3073 -67.6275  ...
# 709439     TS     13.7    -68.1  ...
# ...       ...      ...      ...  ...          ...          ...
# 709504     TS     33.3    -79.2  ...
# 709505     TS   33.678 -79.2179  ...
# 709506     ET     34.4    -79.3  ...
# 709507     ET  34.9324 -79.4729  ...
# 709508     ET     35.3    -79.7  ...
#
#        REUNION_GUST_PER USA_SEAHGT USA_SEARAD_NE USA_SEARAD_SE USA_SEARAD_SW  \
# 709435
# 709436
# 709437
# 709438
# 709439
# ...                 ...        ...           ...           ...           ...
# 709504
# 709505
# 709506
# 709507
# 709508
#
#        USA_SEARAD_NW STORM_SPEED STORM_DIR
# 709435                        11       301
# 709436                        11       304
# 709437                        11       311
# 709438                        12       312
# 709439                        12       304
# ...              ...         ...       ...
# 709504                         8         0
# 709505                        11       356
# 709506                        13       351
# 709507                        10       340
# 709508                         8       333
#
# [74 rows x 163 columns]

# %% [markdown]
# # MetNav

# %%
from data_library import attributes
from cpex_metnav import metnav_to_csv

metnav_to_csv(dir_case='/08_CPEX_CV/01_AEW06_Ian', case_name='Ian')
# Out:
# Files: 0/1 files | 00:00<?
# /uufs/chpc.utah.edu/common/home/zpu-group16/cfeng/08_CPEX_CV/01_AEW06_Ian/data/flight_track_20220916.csv
