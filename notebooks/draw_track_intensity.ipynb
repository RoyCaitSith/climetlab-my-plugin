# %% [markdown]
# # Using climetlab to download the best track

# %%
#wget https://www.ncei.noaa.gov/data/international-best-track-archive-for-climate-stewardship-ibtracs/v04r00/access/csv/ibtracs.ALL.list.v04r00.csv
#wget https://www.ncei.noaa.gov/data/international-best-track-archive-for-climate-stewardship-ibtracs/v04r00/access/csv/ibtracs.NA.list.v04r00.csv

# %%
from data_library import attributes
import climetlab as cml

(dir_case, case_name) = ('/02_GOES_Bias_Correction/27_ChCor', 'Laura')

case_attributes = attributes[(dir_case, case_name)]
ibtracs = cml.load_source('file', case_attributes['ibtracs'])
pd = ibtracs.to_pandas()
pd = pd[(pd.NAME == case_attributes['ibtracs_case']) & (pd.SEASON == case_attributes['ibtracs_season'])]
cml.plot_map(pd, style="cyclone-track")
pd

# %% [markdown]
# # Show the NHC best track data

# %%
from data_library import attributes
import climetlab as cml

(dir_case, case_name) = ('/02_GOES_Bias_Correction/27_ChCor', 'Laura')

case_attributes = attributes[(dir_case, case_name)]
NHC = cml.load_source('file', case_attributes['NHC_best_track'])
pd = NHC.to_pandas()
cml.plot_map(pd, style="cyclone-track")
pd

# %% [markdown]
# # Extract GFDL results and calculate track and intensity errors

# %%
from track_and_intensity import calculate_track_intensity_errors

calculate_track_intensity_errors(dir_case='/02_GOES_Bias_Correction/27_ChCor',
                                 case_name='Laura',
                                 exp_name='NPB_ASRBC4CLD_CLD_08')

# %% [markdown]
# # Compare track forecasts

# %%
from track_and_intensity import compare_track

compare_track(scheme='TROPICS_Ida_scheme_03')

# %% [markdown]
# # Compare MSLP forecast

# %%
from track_and_intensity import compare_MSLP

compare_MSLP(scheme='TROPICS_Ida_scheme_03')

# %% [markdown]
# # Compare MWS forecast

# %%
from track_and_intensity import compare_MWS

compare_MWS(scheme='TROPICS_Ida_scheme_03')
# Out:
# Cycles: 0/3 files | 00:00<?
